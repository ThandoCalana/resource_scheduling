# %%
import pandas as pd
excel_file_path = 'Cert Sample.xlsx'
df = pd.read_excel(excel_file_path)
display(df.head())
# Out:
#         Date               Name  \
# 0 2023-10-01  Azabenathi Pupuma
# 1 2023-10-01  Azabenathi Pupuma
# 2 2023-10-01  Azabenathi Pupuma
# 3 2023-10-01  Azabenathi Pupuma
# 4 2023-10-01  Azabenathi Pupuma
#
#                                  Certification Name  Technology  Status  \
# 0                             Alteryx Designer Core     Alteryx  Active
# 1                            AWS Cloud Practitioner         AWS  Active
# 2  Salesforce Certified Tableau Desktop Foundations  Salesforce  Active
# 3     Alteryx Designer Cloud, Trifacta Classic Core     Alteryx  Active
# 4                                      SnowPro Core   Snowflake  Active
#
#   Expiration Date Expiration Date Indicator Planned Exam Date  \
# 0      2026-06-27                    Actual               NaT
# 1      2027-04-11                    Actual               NaT
# 2      2035-12-05                    Actual               NaT
# 3      2035-12-05                    Actual               NaT
# 4      2035-12-05                    Actual               NaT
#
#    Validity (Years)  Cost ($) Record Date Last Updated  Latest Flag  \
# 0               2.0       0.0  2024-05-13   2024-07-09            1
# 1               3.0     100.0  2024-02-26   2024-07-09            1
# 2              10.0      75.0  2024-07-09   2025-09-23            1
# 3               2.0       0.0  2024-09-16   2024-10-02            1
# 4               2.0     175.0  2024-09-16   2024-11-08            1
#
#   Employment Status  Partner  Field7
# 0            Active      6.0     NaN
# 1            Active      0.0     NaN
# 2            Active      0.0     NaN
# 3            Active      6.0     NaN
# 4            Active      2.0     NaN

# %%
duplicate_rows = df[df.duplicated()]
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")

if not duplicate_rows.empty:
    print("\nFirst 5 duplicate rows (if any):")
    display(duplicate_rows.head())
# Out:
# Number of duplicate rows: 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382614 entries, 0 to 382613
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Date                       382614 non-null  datetime64[ns]
#  1   Name                       382614 non-null  object
#  2   Certification Name         382614 non-null  object
#  3   Technology                 382614 non-null  object
#  4   Status                     382614 non-null  object
#  5   Expiration Date            382614 non-null  datetime64[ns]
#  6   Expiration Date Indicator  382614 non-null  object
#  7   Planned Exam Date          75633 non-null   datetime64[ns]
#  8   Validity (Years)           355920 non-null  float64
#  9   Cost ($)                   360369 non-null  float64
#  10  Record Date                382614 non-null  datetime64[ns]
#  11  Last Updated               382614 non-null  datetime64[ns]
#  12  Latest Flag                382614 non-null  int64
#  13  Employment Status          382614 non-null  object
#  14  Partner                    360369 non-null  float64
#  15  Field7                     0 non-null       float64
# dtypes: datetime64[ns](5), float64(4), int64(1), object(6)
# memory usage: 46.7+ MB

# %%
df.describe()
# Out:
#                                 Date                Expiration Date  \
# count                         382614                         382614
# mean   2029-11-01 23:59:59.999999744  2027-08-28 16:27:54.418604288
# min              2023-10-01 00:00:00            1970-01-01 00:00:00
# 25%              2026-10-17 00:00:00            2026-04-18 00:00:00
# 50%              2029-11-02 00:00:00            2027-11-17 00:00:00
# 75%              2032-11-18 00:00:00            2035-12-05 00:00:00
# max              2035-12-05 00:00:00            2036-02-27 00:00:00
# std                              NaN                            NaN
#
#                    Planned Exam Date  Validity (Years)       Cost ($)  \
# count                          75633     355920.000000  360369.000000
# mean   2009-06-16 19:45:52.941177088          5.312500      47.530864
# min              1970-01-01 00:00:00          2.000000       0.000000
# 25%              1970-01-01 00:00:00          2.000000       0.000000
# 50%              2025-10-30 00:00:00          3.000000       0.000000
# 75%              2026-01-27 00:00:00         10.000000     100.000000
# max              2026-04-30 00:00:00         10.000000     200.000000
# std                              NaN          3.839256      69.788682
#
#                          Record Date                   Last Updated  \
# count                         382614                         382614
# mean   2024-12-20 15:04:11.162790656  2025-04-08 10:36:16.744186368
# min              2024-02-26 00:00:00            2024-07-02 00:00:00
# 25%              2024-06-25 00:00:00            2024-07-10 00:00:00
# 50%              2024-07-23 00:00:00            2025-09-01 00:00:00
# 75%              2025-09-01 00:00:00            2025-09-17 00:00:00
# max              2025-10-10 00:00:00            2025-10-31 00:00:00
# std                              NaN                            NaN
#
#          Latest Flag       Partner  Field7
# count  382614.000000  360369.00000     0.0
# mean        0.976744       1.82716     NaN
# min         0.000000       0.00000     NaN
# 25%         1.000000       0.00000     NaN
# 50%         1.000000       2.00000     NaN
# 75%         1.000000       2.00000     NaN
# max         1.000000       6.00000     NaN
# std         0.150715       2.24868     NaN

# %%
df.describe(include=['object'])
# Out:
#                    Name     Certification Name Technology  Status  \
# count            382614                 382614     382614  382614
# unique               15                     26          5       5
# top     Thembani Faleni  Alteryx Designer Core    Alteryx  Active
# freq              66735                  48939     142368  184119
#
#        Expiration Date Indicator Employment Status
# count                     382614            382614
# unique                         2                 2
# top                       Actual            Active
# freq                      306981            355920

# %%
df.isnull().sum()
# Out:
# Date                              0
# Name                              0
# Certification Name                0
# Technology                        0
# Status                            0
# Expiration Date                   0
# Expiration Date Indicator         0
# Planned Exam Date            306981
# Validity (Years)              26694
# Cost ($)                      22245
# Record Date                       0
# Last Updated                      0
# Latest Flag                       0
# Employment Status                 0
# Partner                       22245
# Field7                       382614
# dtype: int64

# %%
df.nunique()
# Out:
# Date                         4449
# Name                           15
# Certification Name             26
# Technology                      5
# Status                          5
# Expiration Date                44
# Expiration Date Indicator       2
# Planned Exam Date              12
# Validity (Years)                3
# Cost ($)                        6
# Record Date                    25
# Last Updated                   29
# Latest Flag                     2
# Employment Status               2
# Partner                         3
# Field7                          0
# dtype: int64

# %%
display(df['Expiration Date Indicator'].unique())
# Out:
# array(['Actual', 'Projected'], dtype=object)

# %%
count_of_2_in_partner = df[df['Partner'] == 2].shape[0]
print(f"The value '2' appears {count_of_2_in_partner} times in the 'Partner' column.")
# Out:
# The value '2' appears 115674 times in the 'Partner' column.

# %%
# we drop Field7 and planned Exam date feature since they have more than 80% of the missing values.
df.drop(['Field7', 'Planned Exam Date'], axis=1, inplace=True)

# %%
display(df.head())
# Out:
#         Date               Name  \
# 0 2023-10-01  Azabenathi Pupuma
# 1 2023-10-01  Azabenathi Pupuma
# 2 2023-10-01  Azabenathi Pupuma
# 3 2023-10-01  Azabenathi Pupuma
# 4 2023-10-01  Azabenathi Pupuma
#
#                                  Certification Name  Technology  Status  \
# 0                             Alteryx Designer Core     Alteryx  Active
# 1                            AWS Cloud Practitioner         AWS  Active
# 2  Salesforce Certified Tableau Desktop Foundations  Salesforce  Active
# 3     Alteryx Designer Cloud, Trifacta Classic Core     Alteryx  Active
# 4                                      SnowPro Core   Snowflake  Active
#
#   Expiration Date Expiration Date Indicator  Validity (Years)  Cost ($)  \
# 0      2026-06-27                    Actual               2.0       0.0
# 1      2027-04-11                    Actual               3.0     100.0
# 2      2035-12-05                    Actual              10.0      75.0
# 3      2035-12-05                    Actual               2.0       0.0
# 4      2035-12-05                    Actual               2.0     175.0
#
#   Record Date Last Updated  Latest Flag Employment Status  Partner
# 0  2024-05-13   2024-07-09            1            Active      6.0
# 1  2024-02-26   2024-07-09            1            Active      0.0
# 2  2024-07-09   2025-09-23            1            Active      0.0
# 3  2024-09-16   2024-10-02            1            Active      6.0
# 4  2024-09-16   2024-11-08            1            Active      2.0

# %%
partner_zero_rows = df[df['Partner'] == 2]
display(partner_zero_rows)
# Out:
#              Date               Name                      Certification Name  \
# 4      2023-10-01  Azabenathi Pupuma                            SnowPro Core
# 7      2023-10-01  Azabenathi Pupuma               Alteryx Designer Advanced
# 8      2023-10-01        Ben Brooker               Alteryx Designer Advanced
# 11     2023-10-01        Ben Brooker                            SnowPro Core
# 12     2023-10-01        Ben Brooker  Alteryx Auto Insights Micro-Credential
# ...           ...                ...                                     ...
# 382591 2035-12-05    Suzanne Edlmann               Alteryx Designer Advanced
# 382601 2035-12-05    Thembani Faleni               Alteryx Designer Advanced
# 382605 2035-12-05    Thembani Faleni  Snowflake Technical Sales Professional
# 382606 2035-12-05    Thembani Faleni            Snowflake Sales Professional
# 382611 2035-12-05    Thembani Faleni                            SnowPro Core
#
#        Technology             Status Expiration Date  \
# 4       Snowflake             Active      2035-12-05
# 7         Alteryx  Projected Expired      1972-01-01
# 8         Alteryx             Active      2026-06-05
# 11      Snowflake             Active      2035-12-05
# 12        Alteryx             Active      2035-12-05
# ...           ...                ...             ...
# 382591    Alteryx            Expired      2026-06-26
# 382601    Alteryx            Expired      2035-12-05
# 382605  Snowflake            Expired      2035-12-05
# 382606  Snowflake            Expired      2035-12-05
# 382611  Snowflake  Projected Expired      2027-11-30
#
#        Expiration Date Indicator  Validity (Years)  Cost ($) Record Date  \
# 4                         Actual               2.0     175.0  2024-09-16
# 7                      Projected               2.0       0.0  2024-06-25
# 8                         Actual               2.0       0.0  2024-07-09
# 11                        Actual               2.0     175.0  2024-05-13
# 12                        Actual               2.0       0.0  2024-04-02
# ...                          ...               ...       ...         ...
# 382591                    Actual               2.0       0.0  2024-03-04
# 382601                    Actual               2.0       0.0  2024-04-02
# 382605                    Actual              10.0       0.0  2025-10-10
# 382606                    Actual              10.0       0.0  2025-10-10
# 382611                 Projected               2.0     175.0  2025-09-12
#
#        Last Updated  Latest Flag Employment Status  Partner  \
# 4        2024-11-08            1            Active      2.0
# 7        2025-10-17            1            Active      2.0
# 8        2024-07-09            1            Active      2.0
# 11       2024-10-04            1            Active      2.0
# 12       2025-06-27            1            Active      2.0
# ...             ...          ...               ...      ...
# 382591   2024-07-10            1            Active      2.0
# 382601   2025-07-02            1            Active      2.0
# 382605   2025-10-10            1            Active      2.0
# 382606   2025-10-10            1            Active      2.0
# 382611   2025-10-31            1            Active      2.0
#
#                         validityNow
# 4         3646 days 10:49:38.493032
# 7      -19703 days +10:49:38.493032
# 8          176 days 10:49:38.493032
# 11        3646 days 10:49:38.493032
# 12        3646 days 10:49:38.493032
# ...                             ...
# 382591     197 days 10:49:38.493032
# 382601    3646 days 10:49:38.493032
# 382605    3646 days 10:49:38.493032
# 382606    3646 days 10:49:38.493032
# 382611     719 days 10:49:38.493032
#
# [115674 rows x 15 columns]

# %%
df['Cost ($)'] = df['Cost ($)'].fillna(0)
print("Missing values in 'Cost ($)' after filling with 0:")
print(df['Cost ($)'].isnull().sum())
# Out:
# Missing values in 'Cost ($)' after filling with 0:
# 0

# %%
# Calculate 'validityNow' as the difference between 'Expiration Date' and the current date
current_date = pd.Timestamp.now()
df['validityNow'] = df['Expiration Date'] - current_date

display(df.head())
# Out:
#         Date               Name  \
# 0 2023-10-01  Azabenathi Pupuma
# 1 2023-10-01  Azabenathi Pupuma
# 2 2023-10-01  Azabenathi Pupuma
# 3 2023-10-01  Azabenathi Pupuma
# 4 2023-10-01  Azabenathi Pupuma
#
#                                  Certification Name  Technology  Status  \
# 0                             Alteryx Designer Core     Alteryx  Active
# 1                            AWS Cloud Practitioner         AWS  Active
# 2  Salesforce Certified Tableau Desktop Foundations  Salesforce  Active
# 3     Alteryx Designer Cloud, Trifacta Classic Core     Alteryx  Active
# 4                                      SnowPro Core   Snowflake  Active
#
#   Expiration Date Expiration Date Indicator  Validity (Years)  Cost ($)  \
# 0      2026-06-27                    Actual               2.0       0.0
# 1      2027-04-11                    Actual               3.0     100.0
# 2      2035-12-05                    Actual              10.0      75.0
# 3      2035-12-05                    Actual               2.0       0.0
# 4      2035-12-05                    Actual               2.0     175.0
#
#   Record Date Last Updated  Latest Flag Employment Status  Partner  \
# 0  2024-05-13   2024-07-09            1            Active      6.0
# 1  2024-02-26   2024-07-09            1            Active      0.0
# 2  2024-07-09   2025-09-23            1            Active      0.0
# 3  2024-09-16   2024-10-02            1            Active      6.0
# 4  2024-09-16   2024-11-08            1            Active      2.0
#
#                 validityNow
# 0  198 days 10:49:38.493032
# 1  486 days 10:49:38.493032
# 2 3646 days 10:49:38.493032
# 3 3646 days 10:49:38.493032
# 4 3646 days 10:49:38.493032
